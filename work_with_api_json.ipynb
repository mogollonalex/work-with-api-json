# %% [markdown]
# <a href="https://colab.research.google.com/github/mogollonalex/work-with-api-json/blob/main/work_with_api_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %%
response = requests.get('https://api.covid19api.com/summary').text

# %%
response_info = json.loads(response)

# %%
response_info
# Out:
# {'Message': 'Caching in progress',
#  'Global': {'NewConfirmed': 0,
#   'TotalConfirmed': 0,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '0001-01-01T00:00:00Z'},
#  'Date': '0001-01-01T00:00:00Z'}

# %%
type(response_info)
# Out:
# dict

# %%
response_info = requests.get("https://api.covid19api.com/summary").json()

# %%
response_info['Countries']
# Out:
# [{'ID': '9a00ebe4-c475-4775-aa5f-e9d96d07f659',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 155,
#   'TotalConfirmed': 199845,
#   'NewDeaths': 1,
#   'TotalDeaths': 7804,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-06T19:52:45.224Z',
#   'Premium': {}},
#  {'ID': 'e19dfc74-4dfd-4b19-b6ec-886cff588232',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 35,
#   'TotalConfirmed': 332372,
#   'NewDeaths': 0,
#   'TotalDeaths': 3589,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-06T19:52:45.224Z',
#   'Premium': {}},
#  {'ID': '8936474c-87d3-4a3c-8272-efbd9fe13599',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 270693,
#   'NewDeaths': 0,
#   'TotalDeaths': 6879,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-06T19:52:45.224Z',
# ...

# %%
country_list = []
for country_info in response_info["Countries"]:
  country_list.append([country_info["Country"], country_info["TotalConfirmed"]])

# %%
country_list
# Out:
# [['Afghanistan', 199845],
#  ['Albania', 332372],
#  ['Algeria', 270693],
#  ['Andorra', 46227],
#  ['Angola', 103131],
#  ['Antarctica', 11],
#  ['Antigua and Barbuda', 9098],
#  ['Argentina', 9711355],
#  ['Armenia', 443785],
#  ['Australia', 10246170],
#  ['Austria', 5195408],
#  ['Azerbaijan', 821865],
#  ['Bahamas', 37309],
#  ['Bahrain', 682470],
#  ['Bangladesh', 2028114],
#  ['Barbados', 102580],
#  ['Belarus', 994037],
#  ['Belgium', 4553333],
#  ['Belize', 68884],
#  ['Benin', 27782],
#  ['Bhutan', 62095],
#  ['Bolivia', 1108472],
#  ['Bosnia and Herzegovina', 398796],
#  ['Botswana', 326329],
#  ['Brazil', 34699017],
#  ['Brunei Darussalam', 229665],
#  ['Bulgaria', 1262945],
#  ['Burkina Faso', 21631],
#  ['Burundi', 50193],
#  ['Cambodia', 137899],
#  ['Cameroon', 121652],
#  ['Canada', 3681278],
#  ['Cape Verde', 62384],
#  ['Central African Republic', 14923],
#  ['Chad', 7590],
#  ['Chile', 4638238],
#  ['China', 2035981],
#  ['Colombia', 6307372],
# ...

# %%
import pandas as pd

# %%
country_df = pd.DataFrame(data=country_list, columns=['Country', 'TotalConfirmed'])

# %%
country_df.head(10)
# Out:
#                Country  TotalConfirmed
# 0          Afghanistan          199845
# 1              Albania          332372
# 2              Algeria          270693
# 3              Andorra           46227
# 4               Angola          103131
# 5           Antarctica              11
# 6  Antigua and Barbuda            9098
# 7            Argentina         9711355
# 8              Armenia          443785
# 9            Australia        10246170
